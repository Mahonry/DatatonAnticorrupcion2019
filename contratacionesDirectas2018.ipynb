# %%
import pandas as pd
import json
import io
from pandas.io.json import json_normalize
import pymongo 
from pymongo import MongoClient
import pprint
import flatten_json
import numpy as np

# %%
with open("contratacionesDirectas2018.json","r",encoding="utf-8") as file:
    data=json.load(file)

# %%
data[1]['buyer']['name']
# Out:
# 'Comisión Nacional del Agua'

# %%
data
# Out:
# [{'_id': {'$oid': '5dcdaf7d0d84ead5c49c6ebe'},
#   'ocid': 'ocds-07smqs-1127722',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'VALPO VALUACION PROFESIONAL ORGANIZADA SA DE CV'}]}],
#   'contracts': [{'id': 1831169,
#     'awardID': '1831169',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS.',
#     'status': 'terminated',
#     'period': {'startDate': '2017-07-14T12:00:00Z',
#      'endDate': '2017-12-23T11:59:00Z'},
#     'value': {'amount': 800000, 'currency': 'MXN'},
#     'items': [{'id': '5372898',
#       'description': 'AVALUO',
#       'classification': {'id': '33900001',
#        'description': 'Estudios e investigaciones'},
#       'quantity': 1,
#       'unit': {'name': 'Servicio',
#        'value': {'amount': 800000, 'currency': 'MXN'}}}]}],
#   'total': 800000.0},
#  {'_id': {'$oid': '5dcdaf7d0d84ead5c49c6edc'},
#   'ocid': 'ocds-07smqs-1170950',
#   'buyer': {'name': 'Comisión Nacional del Agua'},
#   'awards': [{'suppliers': [{'name': 'KIDZANIA DE MEXICO SA DE CV'}]}],
#   'contracts': [{'id': 1328165,
#     'awardID': '1328165',
#     'title': 'SERVICIO DE INSTALACIÓN, MANTENIMIENTO, OPERACIÓN Y ATENCIÓN DE EXPOSICIÓN',
#     'status': 'terminated',
#     'period': {'startDate': '2017-09-01T12:00:00Z',
#      'endDate': '2017-12-31T11:59:00Z'},
#     'value': {'amount': 1300000, 'currency': 'MXN'}}],
#   'total': 1300000.0},
#  {'_id': {'$oid': '5dcdaf930d84ead5c49c7e78'},
#   'ocid': 'ocds-07smqs-1267917',
#   'buyer': {'name': 'Comisión Nacional del Agua'},
#   'awards': [{'suppliers': [{'name': 'ELPIDIO HUERTA HUERTA'}]}],
#   'contracts': [{'id': 1333948,
#     'awardID': '1333948',
#     'title': 'CONTRATO DE ARRENDAMIENTO INMUEBLE OFICINAS DLBCS 2017',
#     'description': 'CONTRATO DE ARRENDAMIENTO INMUEBLE OFICINAS DLBCS 2017',
#     'status': 'terminated',
#     'period': {'startDate': '2017-01-01T12:00:00Z',
#      'endDate': '2017-12-31T11:59:00Z'},
#     'value': {'amount': 1396824, 'currency': 'MXN'},
#     'dateSigned': '2017-01-01T00:00:00Z'}],
#   'total': 1396824.0},
#  {'_id': {'$oid': '5dcdaf950d84ead5c49c7f81'},
#   'ocid': 'ocds-07smqs-1268620',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'FERNANDO LUIS SANDOVAL MIRANDA'}]}],
#   'contracts': [{'id': 1562722,
#     'awardID': '1562722',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-01-13T12:00:00Z',
#      'endDate': '2017-02-09T11:59:00Z'},
#     'value': {'amount': 38461.54, 'currency': 'MXN'}}],
#   'total': 38461.54},
#  {'_id': {'$oid': '5dcdaf950d84ead5c49c7fa4'},
#   'ocid': 'ocds-07smqs-1268727',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'TASA 100 SC'}]}],
#   'contracts': [{'id': 1787343,
#     'awardID': '1787343',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-01-16T12:00:00Z',
#      'endDate': '2017-02-21T11:59:00Z'},
#     'value': {'amount': 10111.74, 'currency': 'MXN'},
#     'items': [{'id': '5295234',
#       'description': 'AVALUO',
#       'classification': {'id': '33900001',
#        'description': 'Estudios e investigaciones'},
#       'quantity': 1,
#       'unit': {'name': 'Servicio',
#        'value': {'amount': 10111.74, 'currency': 'MXN'}}}]}],
#   'total': 10111.74},
#  {'_id': {'$oid': '5dcdaf950d84ead5c49c7fcc'},
#   'ocid': 'ocds-07smqs-1268776',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'JOSE FERNANDO VIRGEN MEDINA'}]}],
#   'contracts': [{'id': 1552428,
#     'awardID': '1552428',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-01-16T12:00:00Z',
#      'endDate': '2017-08-16T11:59:00Z'},
#     'value': {'amount': 8646.25, 'currency': 'MXN'},
#     'items': [{'id': '5269509',
#       'description': 'AVALUO',
#       'classification': {'id': '33900001',
#        'description': 'Estudios e investigaciones'},
#       'quantity': 1,
#       'unit': {'name': 'Servicio',
#        'value': {'amount': 5646.25, 'currency': 'MXN'}}}]}],
#   'total': 8646.25},
#  {'_id': {'$oid': '5dcdaf950d84ead5c49c7fd6'},
#   'ocid': 'ocds-07smqs-1268792',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'ROBERTO IBARRA CABALLERO'}]}],
#   'contracts': [{'id': 1774763,
#     'awardID': '1774763',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS.',
#     'status': 'terminated',
#     'period': {'startDate': '2017-01-17T12:00:00Z',
#      'endDate': '2017-02-07T11:59:00Z'},
#     'value': {'amount': 4923.08, 'currency': 'MXN'},
#     'items': [{'id': '5279231',
#       'description': 'AVALUO',
#       'classification': {'id': '33900001',
#        'description': 'Estudios e investigaciones'},
#       'quantity': 1,
#       'unit': {'name': 'Servicio',
#        'value': {'amount': 4923.08, 'currency': 'MXN'}}}]}],
#   'total': 4923.08},
#  {'_id': {'$oid': '5dcdaf950d84ead5c49c7ff4'},
#   'ocid': 'ocds-07smqs-1268878',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'PARAMETRIX SC'}]}],
#   'contracts': [{'id': 1528850,
#     'awardID': '1528850',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-05-11T12:00:00Z',
#      'endDate': '2018-02-01T11:59:00Z'},
#     'value': {'amount': 4023.22, 'currency': 'MXN'},
#     'items': [{'id': '5279030',
#       'description': 'AVALUO',
#       'classification': {'id': '33900001',
#        'description': 'Estudios e investigaciones'},
#       'quantity': 1,
#       'unit': {'name': 'Servicio',
#        'value': {'amount': 4023.22, 'currency': 'MXN'}}}]}],
#   'total': 4023.22},
#  {'_id': {'$oid': '5dcdaf950d84ead5c49c7ff9'},
#   'ocid': 'ocds-07smqs-1268886',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'SALVADOR RODARTE ARIAS'}]}],
#   'contracts': [{'id': 1797065,
#     'awardID': '1797065',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS.',
#     'status': 'terminated',
#     'period': {'startDate': '2017-01-31T12:00:00Z',
#      'endDate': '2017-02-14T11:59:00Z'},
#     'value': {'amount': 2000, 'currency': 'MXN'},
#     'items': [{'id': '5309736',
#       'description': 'AVALUO',
#       'classification': {'id': '33900001',
#        'description': 'Estudios e investigaciones'},
#       'quantity': 1,
#       'unit': {'name': 'Servicio',
#        'value': {'amount': 2000, 'currency': 'MXN'}}}]}],
#   'total': 2000.0},
#  {'_id': {'$oid': '5dcdaf990d84ead5c49c82d3'},
#   'ocid': 'ocds-07smqs-1271972',
#   'buyer': {'name': 'Registro Agrario Nacional'},
#   'awards': [{'suppliers': [{'name': 'FUERZAS DE ELITE SEGURIDAD PRIVADA SA DE CV'}]}],
#   'contracts': [{'id': 1382692,
#     'awardID': '1382692',
#     'title': 'SERVICIO DE SEGURIDAD Y VIGILANCIA 2017',
#     'description': 'PRESTACIÓN DEL SERVICIO DE SEGURIDAD Y VIGILANCIA DE LOS EDIFICIOS QUE OCUPA LA DELEGACIÓN DEL REGISTRO AGRARIO NACIONAL EN GUANAJUATO',
#     'status': 'terminated',
#     'period': {'startDate': '2017-03-01T12:00:00Z',
#      'endDate': '2017-12-31T11:59:00Z'},
#     'value': {'amount': 320600, 'currency': 'MXN'},
#     'items': [{'id': '5572640',
#       'description': 'VIGILANCIA 2017',
#       'classification': {'id': '33800001',
#        'description': 'Servicios de vigilancia de bienes inmuebles'},
#       'quantity': 1,
#       'unit': {'name': 'Servicio',
#        'value': {'amount': 320600, 'currency': 'MXN'}}}]}],
#   'total': 320600.0},
#  {'_id': {'$oid': '5dcdaf990d84ead5c49c82d8'},
#   'ocid': 'ocds-07smqs-1272040',
#   'buyer': {'name': 'Registro Agrario Nacional'},
#   'awards': [{'suppliers': [{'name': 'LA CORONELA COMERCIALIZADORA DE PRODUCTOS, LIMPIEZA Y MANTENIMIENTO SA DE CV'}]}],
#   'contracts': [{'id': 1382567,
#     'awardID': '1382567',
#     'title': 'SERVICIO DE LAVANDERIA Y LIMPIEZA 2017',
#     'description': 'PRESTAR EL SERVICIO DE LAVANDERÍA Y LIMPIEZA EN LOS EDIFICIOS QUE OCUPA LA DELEGACIÓN ESTATAL EN GUANAJUATO, POR EL PERIODO COMPRENDIDO DEL 01 DE MARZO AL 31 DE DICIEMBRE DEL 2017',
#     'status': 'terminated',
#     'period': {'startDate': '2017-03-01T12:00:00Z',
#      'endDate': '2017-12-31T11:59:00Z'},
#     'value': {'amount': 305000, 'currency': 'MXN'},
#     'dateSigned': '2017-03-01T00:00:00Z'}],
#   'total': 305000.0},
#  {'_id': {'$oid': '5dcdaf9d0d84ead5c49c8580'},
#   'ocid': 'ocds-07smqs-1275752',
#   'buyer': {'name': 'Procuraduría General de la República'},
#   'awards': [{'suppliers': [{'name': 'EULEN DE SEGURIDAD PRIVADA SA DE CV'}]}],
#   'contracts': [{'id': 1330000,
#     'awardID': '1330000',
#     'title': 'SERVICIO DE VIGILANCIA ININTERRUMPIDO A INMUEBLES',
#     'description': 'SERVICIO DE VIGILANCIA ININTERRUMPIDO A INMUEBLES PROPIEDAD O EN USO DE LA PROCURADURIA GENERAL DE LA REPÚBLICA EN LA DELEGACIÓN ESTATAL EN BAJA CALIFORNIA SUR',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-01T01:01:00Z',
#      'endDate': '2018-03-01T12:59:00Z'},
#     'value': {'amount': 2270424, 'currency': 'MXN'}}],
#   'total': 2270424.0},
#  {'_id': {'$oid': '5dcdafa60d84ead5c49c8acb'},
#   'ocid': 'ocds-07smqs-1282017',
#   'buyer': {'name': 'Comisión Nacional del Agua'},
#   'awards': [{'suppliers': [{'name': 'VICTOR MANUEL PARDO OLGUIN'}]}],
#   'contracts': [{'id': 1336535,
#     'awardID': '1336535',
#     'title': 'MANTENIMIENTO A INSTRUMENTAL DE LABORATORIO 2017',
#     'description': 'MANTENIMIENTO PREVENTIVO, CORRECTIVO Y CALIBRACIÓN DEL EQUIPO E INSTRUMENTAL DE LABORATORIO DE CALIDAD DEL AGUA EN LA DIRECCIÓN LOCAL ZACATECAS 2017',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-06T12:00:00Z',
#      'endDate': '2017-02-10T11:59:00Z'},
#     'value': {'amount': 47500, 'currency': 'MXN'},
#     'dateSigned': '2017-01-25T00:00:00Z'}],
#   'total': 47500.0},
#  {'_id': {'$oid': '5dcdafa60d84ead5c49c8af3'},
#   'ocid': 'ocds-07smqs-1282280',
#   'buyer': {'name': 'Comisión Nacional del Agua'},
#   'awards': [{'suppliers': [{'name': 'EFRAIN AGUILAR HERNANDEZ'}]}],
#   'contracts': [{'id': 1336766,
#     'awardID': '1336766',
#     'title': 'MANTENIMIENTO A PLANTA HIDROGENERADORA 2017',
#     'description': 'MANTENIMIENTO PREVENTIVO Y CORRECTIVO A PLANTA HIDROGENERADORA DEL DEPARTAMENTO DE RADIO SONDEO Y RECUPERACIÓN Y PUESTA EN MARCHA DE MÁQUINA DE ANEMOCINEMÓGRAFO DEL OBSERVATORIO DE LA BUFA 2017',
#     'status': 'terminated',
#     'period': {'startDate': '2017-01-31T12:00:00Z',
#      'endDate': '2017-12-01T11:59:00Z'},
#     'value': {'amount': 123500, 'currency': 'MXN'},
#     'dateSigned': '2017-01-30T00:00:00Z'}],
#   'total': 123500.0},
#  {'_id': {'$oid': '5dcdafd50d84ead5c49ca646'},
#   'ocid': 'ocds-07smqs-1286680',
#   'buyer': {'name': 'Comisión Nacional del Agua'},
#   'awards': [{'suppliers': [{'name': 'ESTUDIOS AZTECA SA DE CV'}]}],
#   'contracts': [{'id': 1394894,
#     'awardID': '1394894',
#     'title': 'SERVICIO DE DIFUSIÓN REGIONAL EN EL ESTADO DE MÉXICO DE LA CAMPAÑA MENSAJES A LA CIUDADANÍA, VERSIÓN “CONAGUA TÉCNICO”, CON SPOTEO DE 30” A TRAVÉS DE LOS CANALES AZTECA SIETE Y AZTECA TRECE DE ESTUDIOS AZTECA, S.A. DE C.V.',
#     'description': 'SERVICIO DE DIFUSIÓN REGIONAL EN EL ESTADO DE MÉXICO DE LA CAMPAÑA MENSAJES A LA CIUDADANÍA, VERSIÓN “CONAGUA TÉCNICO”, CON SPOTEO DE 30” A TRAVÉS DE LOS CANALES AZTECA SIETE Y AZTECA TRECE DE ESTUDIOS AZTECA, S.A. DE C.V.',
#     'status': 'terminated',
#     'period': {'startDate': '2017-03-01T12:00:00Z',
#      'endDate': '2017-03-26T11:59:00Z'},
#     'value': {'amount': 1724334, 'currency': 'MXN'}}],
#   'total': 1724334.0},
#  {'_id': {'$oid': '5dcdafda0d84ead5c49ca97a'},
#   'ocid': 'ocds-07smqs-1287828',
#   'buyer': {'name': 'Registro Agrario Nacional'},
#   'awards': [{'suppliers': [{'name': 'EFRAIN SOTOMAYOR GARCIA'}]}],
#   'contracts': [{'id': 1343838,
#     'awardID': '1343838',
#     'title': 'SERVICIO DE LIMPIEZA',
#     'status': 'terminated',
#     'period': {'startDate': '2017-03-01T12:00:00Z',
#      'endDate': '2017-12-31T11:59:00Z'},
#     'value': {'amount': 320000, 'currency': 'MXN'},
#     'dateSigned': '2017-02-28T00:00:00Z'}],
#   'total': 320000.0},
#  {'_id': {'$oid': '5dcdafda0d84ead5c49ca9b1'},
#   'ocid': 'ocds-07smqs-1287932',
#   'buyer': {'name': 'Registro Agrario Nacional'},
#   'awards': [{'suppliers': [{'name': 'PEDRO IGNACIO AGUIRRE AGUIRRE'}]}],
#   'contracts': [{'id': 1344694,
#     'awardID': '1344694',
#     'title': 'CONTRATO PARA EL SERVICIO DE FUMIGACIÓN',
#     'description': 'CONTRATO CELEBRADO PARA EL SERVICIO DE FUMIGACIÓN EN LAS BODEGAS Y OFICINAS QUE OCUPAN LAS OFICINAS DEL REGISTRO AGRARIO NACIONAL',
#     'status': 'terminated',
#     'period': {'startDate': '2017-03-01T12:00:00Z',
#      'endDate': '2017-12-31T11:59:00Z'},
#     'value': {'amount': 30200, 'currency': 'MXN'},
#     'dateSigned': '2017-03-01T00:00:00Z'}],
#   'total': 30200.0},
#  {'_id': {'$oid': '5dcdafe30d84ead5c49caf24'},
#   'ocid': 'ocds-07smqs-1291114',
#   'buyer': {'name': 'Comisión Nacional del Agua'},
#   'awards': [{'suppliers': [{'name': 'COMERCIALIZADORA DE MEDIOS ESCRITOS SA DE CV'}]}],
#   'contracts': [{'id': 1348664,
#     'awardID': '1348664',
#     'title': 'SUMINISTRO DE PERIÓDICOS Y REVISTAS ',
#     'description': 'SUMINISTRO DE PERIÓDICOS Y REVISTAS ',
#     'status': 'terminated',
#     'period': {'startDate': '2017-08-02T12:00:00Z',
#      'endDate': '2017-08-09T11:59:00Z'},
#     'value': {'amount': 134467.2, 'currency': 'MXN'}}],
#   'total': 134467.2},
#  {'_id': {'$oid': '5dcdaff20d84ead5c49cb866'},
#   'ocid': 'ocds-07smqs-1295901',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO VALENZUELA PORCHAS SA DE CV'}]}],
#   'contracts': [{'id': 1533837,
#     'awardID': '1533837',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-05-03T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff30d84ead5c49cb875'},
#   'ocid': 'ocds-07smqs-1295905',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO VALENZUELA PORCHAS SA DE CV'}]}],
#   'contracts': [{'id': 1533847,
#     'awardID': '1533847',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-05-03T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff30d84ead5c49cb889'},
#   'ocid': 'ocds-07smqs-1295909',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'CELESTE VALUACIONES SA DE CV'}]}],
#   'contracts': [{'id': 1709183,
#     'awardID': '1709183',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-12T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff30d84ead5c49cb88e'},
#   'ocid': 'ocds-07smqs-1295910',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535731,
#     'awardID': '1535731',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-20T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff30d84ead5c49cb893'},
#   'ocid': 'ocds-07smqs-1295912',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535737,
#     'awardID': '1535737',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-25T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff30d84ead5c49cb898'},
#   'ocid': 'ocds-07smqs-1295913',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535725,
#     'awardID': '1535725',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-28T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff30d84ead5c49cb89d'},
#   'ocid': 'ocds-07smqs-1295914',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'CELESTE VALUACIONES SA DE CV'}]}],
#   'contracts': [{'id': 1709261,
#     'awardID': '1709261',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-07T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff30d84ead5c49cb8a2'},
#   'ocid': 'ocds-07smqs-1295915',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535502,
#     'awardID': '1535502',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-11T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff30d84ead5c49cb8a7'},
#   'ocid': 'ocds-07smqs-1295916',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1536272,
#     'awardID': '1536272',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-26T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff30d84ead5c49cb8b1'},
#   'ocid': 'ocds-07smqs-1295918',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535491,
#     'awardID': '1535491',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-21T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff30d84ead5c49cb8b6'},
#   'ocid': 'ocds-07smqs-1295919',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535481,
#     'awardID': '1535481',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-21T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff30d84ead5c49cb8bb'},
#   'ocid': 'ocds-07smqs-1295920',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535476,
#     'awardID': '1535476',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-19T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff30d84ead5c49cb8c0'},
#   'ocid': 'ocds-07smqs-1295921',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'CELESTE VALUACIONES SA DE CV'}]}],
#   'contracts': [{'id': 1709538,
#     'awardID': '1709538',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-12T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff30d84ead5c49cb8c5'},
#   'ocid': 'ocds-07smqs-1295922',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1536261,
#     'awardID': '1536261',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-28T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff30d84ead5c49cb8ca'},
#   'ocid': 'ocds-07smqs-1295923',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1536260,
#     'awardID': '1536260',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-25T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff30d84ead5c49cb8cf'},
#   'ocid': 'ocds-07smqs-1295924',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1536266,
#     'awardID': '1536266',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-28T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff30d84ead5c49cb8d4'},
#   'ocid': 'ocds-07smqs-1295925',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1536270,
#     'awardID': '1536270',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-28T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff30d84ead5c49cb8d9'},
#   'ocid': 'ocds-07smqs-1295927',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535468,
#     'awardID': '1535468',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-12T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff30d84ead5c49cb8de'},
#   'ocid': 'ocds-07smqs-1295928',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535460,
#     'awardID': '1535460',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-25T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff30d84ead5c49cb8e3'},
#   'ocid': 'ocds-07smqs-1295929',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535688,
#     'awardID': '1535688',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-26T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff30d84ead5c49cb8e8'},
#   'ocid': 'ocds-07smqs-1295930',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535682,
#     'awardID': '1535682',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-25T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff30d84ead5c49cb8ed'},
#   'ocid': 'ocds-07smqs-1295931',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535455,
#     'awardID': '1535455',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-28T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff30d84ead5c49cb8f2'},
#   'ocid': 'ocds-07smqs-1295932',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535667,
#     'awardID': '1535667',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-28T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff30d84ead5c49cb8f7'},
#   'ocid': 'ocds-07smqs-1295933',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535444,
#     'awardID': '1535444',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-25T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff30d84ead5c49cb8fc'},
#   'ocid': 'ocds-07smqs-1295934',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535450,
#     'awardID': '1535450',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-19T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff30d84ead5c49cb901'},
#   'ocid': 'ocds-07smqs-1295936',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535620,
#     'awardID': '1535620',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-06T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb90b'},
#   'ocid': 'ocds-07smqs-1295939',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535625,
#     'awardID': '1535625',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-28T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb910'},
#   'ocid': 'ocds-07smqs-1295940',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535591,
#     'awardID': '1535591',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-26T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb915'},
#   'ocid': 'ocds-07smqs-1295941',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535660,
#     'awardID': '1535660',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-27T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb91a'},
#   'ocid': 'ocds-07smqs-1295942',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535602,
#     'awardID': '1535602',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-28T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb91f'},
#   'ocid': 'ocds-07smqs-1295944',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535605,
#     'awardID': '1535605',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-06T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb924'},
#   'ocid': 'ocds-07smqs-1295945',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535613,
#     'awardID': '1535613',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-28T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb929'},
#   'ocid': 'ocds-07smqs-1295946',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535441,
#     'awardID': '1535441',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-21T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb933'},
#   'ocid': 'ocds-07smqs-1295948',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535425,
#     'awardID': '1535425',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-25T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb938'},
#   'ocid': 'ocds-07smqs-1295949',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535417,
#     'awardID': '1535417',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-25T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb93d'},
#   'ocid': 'ocds-07smqs-1295950',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535431,
#     'awardID': '1535431',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-25T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb94c'},
#   'ocid': 'ocds-07smqs-1295953',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535434,
#     'awardID': '1535434',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-28T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb951'},
#   'ocid': 'ocds-07smqs-1295954',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1536258,
#     'awardID': '1536258',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-21T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb956'},
#   'ocid': 'ocds-07smqs-1295955',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1536252,
#     'awardID': '1536252',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-26T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'},
#     'items': [{'id': '5166410',
#       'description': 'AVALUO',
#       'classification': {'id': '33900001',
#        'description': 'Estudios e investigaciones'},
#       'quantity': 1,
#       'unit': {'name': 'Servicio',
#        'value': {'amount': 3500, 'currency': 'MXN'}}}]}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb95b'},
#   'ocid': 'ocds-07smqs-1295956',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1536249,
#     'awardID': '1536249',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-05-04T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'},
#     'items': [{'id': '5166419',
#       'description': 'AVALUO',
#       'classification': {'id': '33900001',
#        'description': 'Estudios e investigaciones'},
#       'quantity': 1,
#       'unit': {'name': 'Servicio',
#        'value': {'amount': 3500, 'currency': 'MXN'}}}]}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb960'},
#   'ocid': 'ocds-07smqs-1295957',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535410,
#     'awardID': '1535410',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-25T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'},
#     'items': [{'id': '5166445',
#       'description': 'AVALUO',
#       'classification': {'id': '33900001',
#        'description': 'Estudios e investigaciones'},
#       'quantity': 1,
#       'unit': {'name': 'Servicio',
#        'value': {'amount': 3500, 'currency': 'MXN'}}}]}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb965'},
#   'ocid': 'ocds-07smqs-1295958',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535389,
#     'awardID': '1535389',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-05-04T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'},
#     'items': [{'id': '5166461',
#       'description': 'AVALUO',
#       'classification': {'id': '33900001',
#        'description': 'Estudios e investigaciones'},
#       'quantity': 1,
#       'unit': {'name': 'Servicio',
#        'value': {'amount': 3500, 'currency': 'MXN'}}}]}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb96a'},
#   'ocid': 'ocds-07smqs-1295959',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535384,
#     'awardID': '1535384',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-06T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'},
#     'items': [{'id': '5166477',
#       'description': 'AVALUO',
#       'classification': {'id': '33900001',
#        'description': 'Estudios e investigaciones'},
#       'quantity': 1,
#       'unit': {'name': 'Servicio',
#        'value': {'amount': 3500, 'currency': 'MXN'}}}]}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb96f'},
#   'ocid': 'ocds-07smqs-1295960',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535393,
#     'awardID': '1535393',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-19T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'},
#     'items': [{'id': '5166480',
#       'description': 'AVALUO',
#       'classification': {'id': '33900001',
#        'description': 'Estudios e investigaciones'},
#       'quantity': 1,
#       'unit': {'name': 'Servicio',
#        'value': {'amount': 3500, 'currency': 'MXN'}}}]}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb974'},
#   'ocid': 'ocds-07smqs-1295961',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535401,
#     'awardID': '1535401',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-25T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'},
#     'items': [{'id': '5166503',
#       'description': 'AVALUO',
#       'classification': {'id': '33900001',
#        'description': 'Estudios e investigaciones'},
#       'quantity': 1,
#       'unit': {'name': 'Servicio',
#        'value': {'amount': 3500, 'currency': 'MXN'}}}]}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb979'},
#   'ocid': 'ocds-07smqs-1295962',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1537148,
#     'awardID': '1537148',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-25T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'},
#     'items': [{'id': '5166600',
#       'description': 'AVALUO',
#       'classification': {'id': '33900001',
#        'description': 'Estudios e investigaciones'},
#       'quantity': 1,
#       'unit': {'name': 'Servicio',
#        'value': {'amount': 3500, 'currency': 'MXN'}}}]}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb97e'},
#   'ocid': 'ocds-07smqs-1295963',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1536247,
#     'awardID': '1536247',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-28T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'},
#     'items': [{'id': '5166607',
#       'description': 'AVALUO',
#       'classification': {'id': '33900001',
#        'description': 'Estudios e investigaciones'},
#       'quantity': 1,
#       'unit': {'name': 'Servicio',
#        'value': {'amount': 3500, 'currency': 'MXN'}}}]}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb983'},
#   'ocid': 'ocds-07smqs-1295964',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'CELESTE VALUACIONES SA DE CV'}]}],
#   'contracts': [{'id': 1696879,
#     'awardID': '1696879',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS.',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-10T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'},
#     'items': [{'id': '5145285',
#       'description': 'AVALUO',
#       'classification': {'id': '33900001',
#        'description': 'Estudios e investigaciones'},
#       'quantity': 1,
#       'unit': {'name': 'Servicio',
#        'value': {'amount': 3500, 'currency': 'MXN'}}}]}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb988'},
#   'ocid': 'ocds-07smqs-1295965',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535372,
#     'awardID': '1535372',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-25T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'},
#     'items': [{'id': '5145968',
#       'description': 'AVALUO',
#       'classification': {'id': '33900001',
#        'description': 'Estudios e investigaciones'},
#       'quantity': 1,
#       'unit': {'name': 'Servicio',
#        'value': {'amount': 3500, 'currency': 'MXN'}}}]}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb98d'},
#   'ocid': 'ocds-07smqs-1295966',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535347,
#     'awardID': '1535347',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-26T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb992'},
#   'ocid': 'ocds-07smqs-1295967',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535342,
#     'awardID': '1535342',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-11T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb997'},
#   'ocid': 'ocds-07smqs-1295969',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535334,
#     'awardID': '1535334',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-25T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb99c'},
#   'ocid': 'ocds-07smqs-1295970',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535328,
#     'awardID': '1535328',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-28T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb9a1'},
#   'ocid': 'ocds-07smqs-1295971',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535324,
#     'awardID': '1535324',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-25T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff40d84ead5c49cb9a6'},
#   'ocid': 'ocds-07smqs-1295972',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535299,
#     'awardID': '1535299',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-28T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff50d84ead5c49cb9ab'},
#   'ocid': 'ocds-07smqs-1295973',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'CELESTE VALUACIONES SA DE CV'}]}],
#   'contracts': [{'id': 1708705,
#     'awardID': '1708705',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-26T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff50d84ead5c49cb9b0'},
#   'ocid': 'ocds-07smqs-1295974',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'CELESTE VALUACIONES SA DE CV'}]}],
#   'contracts': [{'id': 1708850,
#     'awardID': '1708850',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-24T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdaff50d84ead5c49cb9b5'},
#   'ocid': 'ocds-07smqs-1295975',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1536235,
#     'awardID': '1536235',
# ...
#   'contracts': [{'id': 1699715,
#     'awardID': '1699715',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-05-03T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdb06c0d84ead5c49cfec0'},
#   'ocid': 'ocds-07smqs-1301546',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'ALENCA SC'}]}],
#   'contracts': [{'id': 1528741,
#     'awardID': '1528741',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-05-12T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'},
#     'items': [{'id': '5138747',
#       'description': 'AVALUO',
#       'classification': {'id': '33900001',
#        'description': 'Estudios e investigaciones'},
#       'quantity': 1,
#       'unit': {'name': 'Servicio',
#        'value': {'amount': 3500, 'currency': 'MXN'}}}]}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdb06c0d84ead5c49cfec5'},
#   'ocid': 'ocds-07smqs-1301548',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'M&M INGENIERIA Y VALUACION SA DE CV'}]}],
#   'contracts': [{'id': 1699722,
#     'awardID': '1699722',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-19T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdb06c0d84ead5c49cfed9'},
#   'ocid': 'ocds-07smqs-1301552',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'ALENCA SC'}]}],
#   'contracts': [{'id': 1528739,
#     'awardID': '1528739',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-05-12T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'},
#     'items': [{'id': '5138763',
#       'description': 'AVALUO',
#       'classification': {'id': '33900001',
#        'description': 'Estudios e investigaciones'},
#       'quantity': 1,
#       'unit': {'name': 'Servicio',
#        'value': {'amount': 3500, 'currency': 'MXN'}}}]}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdb06c0d84ead5c49cfede'},
#   'ocid': 'ocds-07smqs-1301553',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'M&M INGENIERIA Y VALUACION SA DE CV'}]}],
#   'contracts': [{'id': 1699731,
#     'awardID': '1699731',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-19T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdb06c0d84ead5c49cfee3'},
#   'ocid': 'ocds-07smqs-1301555',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'M&M INGENIERIA Y VALUACION SA DE CV'}]}],
#   'contracts': [{'id': 1699746,
#     'awardID': '1699746',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-19T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdb06c0d84ead5c49cfef2'},
#   'ocid': 'ocds-07smqs-1301558',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'ALENCA SC'}]}],
#   'contracts': [{'id': 1528732,
#     'awardID': '1528732',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-05-16T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'},
#     'items': [{'id': '5138768',
#       'description': 'AVALUO',
#       'classification': {'id': '33900001',
#        'description': 'Estudios e investigaciones'},
#       'quantity': 1,
#       'unit': {'name': 'Servicio',
#        'value': {'amount': 3500, 'currency': 'MXN'}}}]}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdb06c0d84ead5c49cfefc'},
#   'ocid': 'ocds-07smqs-1301560',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'M&M INGENIERIA Y VALUACION SA DE CV'}]}],
#   'contracts': [{'id': 1699761,
#     'awardID': '1699761',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-12T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdb06c0d84ead5c49cff06'},
#   'ocid': 'ocds-07smqs-1301563',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'M&M INGENIERIA Y VALUACION SA DE CV'}]}],
#   'contracts': [{'id': 1699771,
#     'awardID': '1699771',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-17T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdb06c0d84ead5c49cff10'},
#   'ocid': 'ocds-07smqs-1301565',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'ALENCA SC'}]}],
#   'contracts': [{'id': 1528730,
#     'awardID': '1528730',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-05-16T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'},
#     'items': [{'id': '5138775',
#       'description': 'AVALUO',
#       'classification': {'id': '33900001',
#        'description': 'Estudios e investigaciones'},
#       'quantity': 1,
#       'unit': {'name': 'Servicio',
#        'value': {'amount': 3500, 'currency': 'MXN'}}}]}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdb06c0d84ead5c49cff1a'},
#   'ocid': 'ocds-07smqs-1301568',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'M&M INGENIERIA Y VALUACION SA DE CV'}]}],
#   'contracts': [{'id': 1699779,
#     'awardID': '1699779',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-17T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdb06c0d84ead5c49cff2e'},
#   'ocid': 'ocds-07smqs-1301574',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'ALENCA SC'}]}],
#   'contracts': [{'id': 1528726,
#     'awardID': '1528726',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-05-16T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'},
#     'items': [{'id': '5138777',
#       'description': 'AVALUO',
#       'classification': {'id': '33900001',
#        'description': 'Estudios e investigaciones'},
#       'quantity': 1,
#       'unit': {'name': 'Servicio',
#        'value': {'amount': 3500, 'currency': 'MXN'}}}]}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdb06c0d84ead5c49cff38'},
#   'ocid': 'ocds-07smqs-1301577',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'M&M INGENIERIA Y VALUACION SA DE CV'}]}],
#   'contracts': [{'id': 1701006,
#     'awardID': '1701006',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-06T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdb06d0d84ead5c49cff47'},
#   'ocid': 'ocds-07smqs-1301581',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'ALENCA SC'}]}],
#   'contracts': [{'id': 1694305,
#     'awardID': '1694305',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS.',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-14T12:00:00Z',
#      'endDate': '2017-05-16T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'},
#     'items': [{'id': '5139102',
#       'description': 'AVALUO',
#       'classification': {'id': '33900001',
#        'description': 'Estudios e investigaciones'},
#       'quantity': 1,
#       'unit': {'name': 'Servicio',
#        'value': {'amount': 3500, 'currency': 'MXN'}}}]}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdb06d0d84ead5c49cff4c'},
#   'ocid': 'ocds-07smqs-1301582',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1537185,
#     'awardID': '1537185',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-05-03T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdb06d0d84ead5c49cff60'},
#   'ocid': 'ocds-07smqs-1301587',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1537184,
#     'awardID': '1537184',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-05-03T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdb06d0d84ead5c49cff6f'},
#   'ocid': 'ocds-07smqs-1301590',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1537192,
#     'awardID': '1537192',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-12T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdb06d0d84ead5c49cff79'},
#   'ocid': 'ocds-07smqs-1301592',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'ALENCA SC'}]}],
#   'contracts': [{'id': 1528721,
#     'awardID': '1528721',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-05-16T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'},
#     'items': [{'id': '5139165',
#       'description': 'AVALUO',
#       'classification': {'id': '33900001',
#        'description': 'Estudios e investigaciones'},
#       'quantity': 1,
#       'unit': {'name': 'Servicio',
#        'value': {'amount': 3500, 'currency': 'MXN'}}}]}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdb06d0d84ead5c49cff7e'},
#   'ocid': 'ocds-07smqs-1301593',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1537190,
#     'awardID': '1537190',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-04-12T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdb06d0d84ead5c49cff8d'},
#   'ocid': 'ocds-07smqs-1301598',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'CELESTE VALUACIONES SA DE CV'}]}],
#   'contracts': [{'id': 1695195,
#     'awardID': '1695195',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-05-03T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdb06d0d84ead5c49cff97'},
#   'ocid': 'ocds-07smqs-1301600',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'ALENCA SC'}]}],
#   'contracts': [{'id': 1528718,
#     'awardID': '1528718',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-05-16T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'},
#     'items': [{'id': '5139214',
#       'description': 'AVALUO',
#       'classification': {'id': '33900001',
#        'description': 'Estudios e investigaciones'},
#       'quantity': 1,
#       'unit': {'name': 'Servicio',
#        'value': {'amount': 3500, 'currency': 'MXN'}}}]}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdb06d0d84ead5c49cff9c'},
#   'ocid': 'ocds-07smqs-1301601',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'CELESTE VALUACIONES SA DE CV'}]}],
#   'contracts': [{'id': 1695201,
#     'awardID': '1695201',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-05-03T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdb06d0d84ead5c49cffb5'},
#   'ocid': 'ocds-07smqs-1301607',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535508,
#     'awardID': '1535508',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-05-03T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdb06d0d84ead5c49cffba'},
#   'ocid': 'ocds-07smqs-1301608',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'ALENCA SC'}]}],
#   'contracts': [{'id': 1528716,
#     'awardID': '1528716',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-05-16T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'},
#     'items': [{'id': '5139222',
#       'description': 'AVALUO',
#       'classification': {'id': '33900001',
#        'description': 'Estudios e investigaciones'},
#       'quantity': 1,
#       'unit': {'name': 'Servicio',
#        'value': {'amount': 3500, 'currency': 'MXN'}}}]}],
#   'total': 3500.0},
#  {'_id': {'$oid': '5dcdb06d0d84ead5c49cffc9'},
#   'ocid': 'ocds-07smqs-1301611',
#   'buyer': {'name': 'Instituto de Administración y Avalúos de Bienes Nacionales'},
#   'awards': [{'suppliers': [{'name': 'GRUPO AVALUO SC'}]}],
#   'contracts': [{'id': 1535506,
#     'awardID': '1535506',
#     'title': 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS',
#     'status': 'terminated',
#     'period': {'startDate': '2017-02-15T12:00:00Z',
#      'endDate': '2017-05-03T11:59:00Z'},
#     'value': {'amount': 3500, 'currency': 'MXN'}}],
#   'total': 3500.0},
#  ...]

# %%
def sacarTotal(s):
    for s in data:
        return s['total']

# %%
def leer(s):
    return s['buyer']['name']

# %%
sacarTotal(data)
# Out:
# 800000.0

# %%
z=0
y = []
for i in data:
    y.append(data[z]["total"])
    z=z+1

# %%
ocid=[]
z=0
for i in data:
    ocid.append(data[z]["ocid"])
    z=z+1

# %%
contracts=[]
z=0
for i in data:
    contracts.append(data[z]["contracts"][0]["title"])
    z=z+1

# %%
data[0]["contracts"][0]["title"]
# Out:
# 'SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE AVALÚOS.'

# %%
x = []
for i in data:
    x.append(leer(i))

# %%
X = pd.DataFrame(x)

# %%
X["monto real"]=y

# %%
X['monto promedio(estandar 2018)'] = 346500
X["Ocid"]=ocid
X["Contracts"]=contracts

# %%
X["monto minimo"]=190000

# %%
X
# Out:
#                                                         0   monto real  \
# 0       Instituto de Administración y Avalúos de Biene...    800000.00
# 1                              Comisión Nacional del Agua   1300000.00
# 2                              Comisión Nacional del Agua   1396824.00
# 3       Instituto de Administración y Avalúos de Biene...     38461.54
# 4       Instituto de Administración y Avalúos de Biene...     10111.74
# ...                                                   ...          ...
# 134120               Instituto Mexicano del Seguro Social    379310.34
# 134121               Instituto Mexicano del Seguro Social   2586206.89
# 134122               Instituto Mexicano del Seguro Social   2574012.14
# 134123               Instituto Mexicano del Seguro Social  19353730.85
# 134124               Instituto Mexicano del Seguro Social   3046620.00
#
#         monto promedio(estandar 2018)                 Ocid  \
# 0                              346500  ocds-07smqs-1127722
# 1                              346500  ocds-07smqs-1170950
# 2                              346500  ocds-07smqs-1267917
# 3                              346500  ocds-07smqs-1268620
# 4                              346500  ocds-07smqs-1268727
# ...                               ...                  ...
# 134120                         346500  ocds-07smqs-1842700
# 134121                         346500  ocds-07smqs-1842702
# 134122                         346500  ocds-07smqs-1842719
# 134123                         346500  ocds-07smqs-1842726
# 134124                         346500  ocds-07smqs-1842745
#
#                                                 Contracts  monto minimo
# 0       SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE...        190000
# 1       SERVICIO DE INSTALACIÓN, MANTENIMIENTO, OPERAC...        190000
# 2       CONTRATO DE ARRENDAMIENTO INMUEBLE OFICINAS DL...        190000
# 3       SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE...        190000
# 4       SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE...        190000
# ...                                                   ...           ...
# 134120  CONTRATO TECNOLOGIA Y CALIDAD DE LA SALUD S.A....        190000
# 134121  S9M0016 AA-050GYR002-E475-2018 SERV. RECOLECCI...        190000
# 134122  AA-050GYR013-E238-2018 VÍVERES RÉGIMEN ORDINAR...        190000
# 134123  Adquisición de Víveres Grupo de Suministro 480...        190000
# 134124  Contratación del Servicio Integral de Anestesi...        190000
#
# [134125 rows x 6 columns]

# %%
indicador_minimo=[]
p=0
z=0
for i in X["monto real"]:
    if i >= 190000:
        z=1
        indicador_minimo.append(z)
    else:
        z=0
        indicador_minimo.append(z)

# %%
len(indicador_minimo)
# Out:
# 134125

# %%
X["indicador minimo"]=indicador_minimo

# %%
X
# Out:
#                                                         0   monto real  \
# 0       Instituto de Administración y Avalúos de Biene...    800000.00
# 1                              Comisión Nacional del Agua   1300000.00
# 2                              Comisión Nacional del Agua   1396824.00
# 3       Instituto de Administración y Avalúos de Biene...     38461.54
# 4       Instituto de Administración y Avalúos de Biene...     10111.74
# ...                                                   ...          ...
# 134120               Instituto Mexicano del Seguro Social    379310.34
# 134121               Instituto Mexicano del Seguro Social   2586206.89
# 134122               Instituto Mexicano del Seguro Social   2574012.14
# 134123               Instituto Mexicano del Seguro Social  19353730.85
# 134124               Instituto Mexicano del Seguro Social   3046620.00
#
#         monto promedio(estandar 2018)                 Ocid  \
# 0                              346500  ocds-07smqs-1127722
# 1                              346500  ocds-07smqs-1170950
# 2                              346500  ocds-07smqs-1267917
# 3                              346500  ocds-07smqs-1268620
# 4                              346500  ocds-07smqs-1268727
# ...                               ...                  ...
# 134120                         346500  ocds-07smqs-1842700
# 134121                         346500  ocds-07smqs-1842702
# 134122                         346500  ocds-07smqs-1842719
# 134123                         346500  ocds-07smqs-1842726
# 134124                         346500  ocds-07smqs-1842745
#
#                                                 Contracts  monto minimo  \
# 0       SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE...        190000
# 1       SERVICIO DE INSTALACIÓN, MANTENIMIENTO, OPERAC...        190000
# 2       CONTRATO DE ARRENDAMIENTO INMUEBLE OFICINAS DL...        190000
# 3       SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE...        190000
# 4       SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE...        190000
# ...                                                   ...           ...
# 134120  CONTRATO TECNOLOGIA Y CALIDAD DE LA SALUD S.A....        190000
# 134121  S9M0016 AA-050GYR002-E475-2018 SERV. RECOLECCI...        190000
# 134122  AA-050GYR013-E238-2018 VÍVERES RÉGIMEN ORDINAR...        190000
# 134123  Adquisición de Víveres Grupo de Suministro 480...        190000
# 134124  Contratación del Servicio Integral de Anestesi...        190000
#
#         indicador minimo
# 0                      1
# 1                      1
# 2                      1
# 3                      0
# 4                      0
# ...                  ...
# 134120                 1
# 134121                 1
# 134122                 1
# 134123                 1
# 134124                 1
#
# [134125 rows x 7 columns]

# %%
indicador_estandar=[]
p=0
z=0
for i in X["monto real"]:
    if i >= 346500:
        z=1
        indicador_estandar.append(z)
    else:
        z=0
        indicador_estandar.append(z)

# %%
X["indicador estandar"]=indicador_estandar

# %%
X
# Out:
#                                                         0   monto real  \
# 0       Instituto de Administración y Avalúos de Biene...    800000.00
# 1                              Comisión Nacional del Agua   1300000.00
# 2                              Comisión Nacional del Agua   1396824.00
# 3       Instituto de Administración y Avalúos de Biene...     38461.54
# 4       Instituto de Administración y Avalúos de Biene...     10111.74
# ...                                                   ...          ...
# 134120               Instituto Mexicano del Seguro Social    379310.34
# 134121               Instituto Mexicano del Seguro Social   2586206.89
# 134122               Instituto Mexicano del Seguro Social   2574012.14
# 134123               Instituto Mexicano del Seguro Social  19353730.85
# 134124               Instituto Mexicano del Seguro Social   3046620.00
#
#         monto promedio(estandar 2018)                 Ocid  \
# 0                              346500  ocds-07smqs-1127722
# 1                              346500  ocds-07smqs-1170950
# 2                              346500  ocds-07smqs-1267917
# 3                              346500  ocds-07smqs-1268620
# 4                              346500  ocds-07smqs-1268727
# ...                               ...                  ...
# 134120                         346500  ocds-07smqs-1842700
# 134121                         346500  ocds-07smqs-1842702
# 134122                         346500  ocds-07smqs-1842719
# 134123                         346500  ocds-07smqs-1842726
# 134124                         346500  ocds-07smqs-1842745
#
#                                                 Contracts  monto minimo  \
# 0       SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE...        190000
# 1       SERVICIO DE INSTALACIÓN, MANTENIMIENTO, OPERAC...        190000
# 2       CONTRATO DE ARRENDAMIENTO INMUEBLE OFICINAS DL...        190000
# 3       SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE...        190000
# 4       SERVICIOS PROFESIONALES PARA LA ELABORACIÓN DE...        190000
# ...                                                   ...           ...
# 134120  CONTRATO TECNOLOGIA Y CALIDAD DE LA SALUD S.A....        190000
# 134121  S9M0016 AA-050GYR002-E475-2018 SERV. RECOLECCI...        190000
# 134122  AA-050GYR013-E238-2018 VÍVERES RÉGIMEN ORDINAR...        190000
# 134123  Adquisición de Víveres Grupo de Suministro 480...        190000
# 134124  Contratación del Servicio Integral de Anestesi...        190000
#
#         indicador minimo  indicador estandar
# 0                      1                   1
# 1                      1                   1
# 2                      1                   1
# 3                      0                   0
# 4                      0                   0
# ...                  ...                 ...
# 134120                 1                   1
# 134121                 1                   1
# 134122                 1                   1
# 134123                 1                   1
# 134124                 1                   1
#
# [134125 rows x 8 columns]

# %%
flag_1contracts["contracts"][0]

# %%
sum = 0
for i in f

# %%
X.to_csv('flag.csv', index=False)
